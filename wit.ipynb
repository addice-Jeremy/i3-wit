# %%
# !pip3 install torch numpy pandas
# Out:
# Collecting torch
#   Downloading torch-2.6.0-cp310-none-macosx_11_0_arm64.whl (66.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 25.6 MB/s eta 0:00:0000:0100:01
# Collecting numpy
#   Downloading numpy-2.2.4-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 35.7 MB/s eta 0:00:00a 0:00:01
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 33.7 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting sympy==1.13.1
#   Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Collecting fsspec
#   Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 17.6 MB/s eta 0:00:00
# Collecting typing-extensions>=4.10.0
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 7.9 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 17.9 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Collecting six>=1.5
#   Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Installing collected packages: pytz, mpmath, tzdata, typing-extensions, sympy, six, numpy, networkx, MarkupSafe, fsspec, filelock, python-dateutil, jinja2, torch, pandas
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.4 pandas-2.2.3 python-dateutil-2.9.0.post0 pytz-2025.1 six-1.17.0 sympy-1.13.1 torch-2.6.0 typing-extensions-4.12.2 tzdata-2025.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# !pip3 install tensorflow witwidget
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl (252.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 MB 19.1 MB/s eta 0:00:0000:0100:01
# Collecting witwidget
#   Using cached witwidget-1.8.1-py3-none-any.whl (1.5 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3
#   Downloading protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 23.2 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.71.0-cp310-cp310-macosx_12_0_universal2.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 37.2 MB/s eta 0:00:00a 0:00:01
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 37.1 MB/s eta 0:00:00a 0:00:01
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorboard~=2.19.0
#   Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 37.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Collecting h5py>=3.11.0
#   Downloading h5py-3.13.0-cp310-cp310-macosx_11_0_arm64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 36.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.2.0-py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 kB 22.4 MB/s eta 0:00:00
# Collecting numpy<2.2.0,>=1.26.0
#   Downloading numpy-2.1.3-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 36.2 MB/s eta 0:00:00a 0:00:01
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Collecting packaging
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting keras>=3.5.0
#   Downloading keras-3.9.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.8 MB/s eta 0:00:0000:01
# Collecting ml-dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.1-cp310-cp310-macosx_10_9_universal2.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.5/671.5 kB 31.0 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.17.2-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting ipywidgets>=7.0.0
#   Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Collecting oauth2client>=4.1.3
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Collecting google-api-python-client>=1.7.8
#   Using cached google_api_python_client-2.165.0-py2.py3-none-any.whl (13.1 MB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5
#   Using cached google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Collecting httplib2<1.0.0,>=0.19.0
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Collecting uritemplate<5,>=3.0.1
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting comm>=0.1.3
#   Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Collecting ipython>=6.1.0
#   Downloading ipython-8.34.0-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.7/826.7 kB 31.9 MB/s eta 0:00:00
# Collecting traitlets>=4.3.1
#   Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Collecting widgetsnbextension~=4.0.12
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Collecting jupyterlab-widgets~=3.0.12
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Collecting optree
#   Downloading optree-0.14.1-cp310-cp310-macosx_11_0_arm64.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.5/327.5 kB 28.7 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting rich
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 24.3 MB/s eta 0:00:00
# Collecting pyasn1>=0.1.7
#   Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Collecting pyasn1-modules>=0.0.5
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Collecting rsa>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp310-cp310-macosx_10_9_universal2.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.0/198.0 kB 18.0 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Using cached googleapis_common_protos-1.69.2-py3-none-any.whl (293 kB)
# Collecting proto-plus<2.0.0,>=1.22.3
#   Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2
#   Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Collecting matplotlib-inline
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Collecting jedi>=0.16
#   Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Collecting stack_data
#   Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting pygments>=2.4.0
#   Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41
#   Using cached prompt_toolkit-3.0.50-py3-none-any.whl (387 kB)
# Collecting pexpect>4.3
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting decorator
#   Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 13.8 MB/s eta 0:00:00
# Collecting parso<0.9.0,>=0.8.4
#   Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting ptyprocess>=0.5
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting asttokens>=2.1.0
#   Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Collecting executing>=1.2.0
#   Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Collecting pure-eval
#   Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, namex, libclang, flatbuffers, wrapt, widgetsnbextension, wheel, werkzeug, urllib3, uritemplate, traitlets, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, pyparsing, pygments, pyasn1, protobuf, prompt_toolkit, pexpect, parso, packaging, optree, opt-einsum, numpy, mdurl, markdown, jupyterlab-widgets, idna, grpcio, google-pasta, gast, executing, exceptiongroup, decorator, charset-normalizer, certifi, cachetools, asttokens, absl-py, tensorboard, stack_data, rsa, requests, pyasn1-modules, proto-plus, ml-dtypes, matplotlib-inline, markdown-it-py, jedi, httplib2, h5py, googleapis-common-protos, comm, astunparse, rich, oauth2client, ipython, google-auth, keras, ipywidgets, google-auth-httplib2, google-api-core, tensorflow, google-api-python-client, witwidget
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# Successfully installed absl-py-2.2.0 asttokens-3.0.0 astunparse-1.6.3 cachetools-5.5.2 certifi-2025.1.31 charset-normalizer-3.4.1 comm-0.2.2 decorator-5.2.1 exceptiongroup-1.2.2 executing-2.2.0 flatbuffers-25.2.10 gast-0.6.0 google-api-core-2.24.2 google-api-python-client-2.165.0 google-auth-2.38.0 google-auth-httplib2-0.2.0 google-pasta-0.2.0 googleapis-common-protos-1.69.2 grpcio-1.71.0 h5py-3.13.0 httplib2-0.22.0 idna-3.10 ipython-8.34.0 ipywidgets-8.1.5 jedi-0.19.2 jupyterlab-widgets-3.0.13 keras-3.9.0 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 matplotlib-inline-0.1.7 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.8 numpy-2.1.3 oauth2client-4.1.3 opt-einsum-3.4.0 optree-0.14.1 packaging-24.2 parso-0.8.4 pexpect-4.9.0 prompt_toolkit-3.0.50 proto-plus-1.26.1 protobuf-5.29.4 ptyprocess-0.7.0 pure-eval-0.2.3 pyasn1-0.6.1 pyasn1-modules-0.4.1 pygments-2.19.1 pyparsing-3.2.1 requests-2.32.3 rich-13.9.4 rsa-4.9 stack_data-0.6.3 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.5.0 traitlets-5.14.3 uritemplate-4.1.1 urllib3-2.3.0 wcwidth-0.2.13 werkzeug-3.1.3 wheel-0.45.1 widgetsnbextension-4.0.13 witwidget-1.8.1 wrapt-1.17.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
import time
import numpy as np
from src.utils import save_model, load_model

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class MovieLensDataset(Dataset):
    def __init__(self, df):
        self.users = torch.tensor(df['user_id'].values, dtype=torch.long, device=device)
        self.items = torch.tensor(df['movie_id'].values, dtype=torch.long, device=device)
        self.ratings = torch.tensor(df['rating'].values, dtype=torch.float, device=device)

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        return self.users[idx], self.items[idx], self.ratings[idx]    


def prepare_data(data):
    users = data['user_id'].unique()
    movies = data['movie_id'].unique()
    user_to_index = {original: idx for idx, original in enumerate(users)}
    movie_to_index = {original: idx for idx, original in enumerate(movies)}

    index_to_user = {idx: original for original, idx in user_to_index.items()}
    index_to_movie = {idx: original for original, idx in movie_to_index.items()}

    mappings = {
        'user_to_idx': user_to_index,
        'idx_to_user': index_to_user,
        'item_to_idx': movie_to_index,
        'idx_to_item': index_to_movie
    }

    data['user_id'] = data['user_id'].map(user_to_index)
    data['movie_id'] = data['movie_id'].map(movie_to_index)

    train_size = int(0.8 * len(data))
    train_data = data.iloc[:train_size]
    test_data = data.iloc[train_size:]

    train_dataset = MovieLensDataset(train_data)
    test_dataset = MovieLensDataset(test_data)
    dataset = MovieLensDataset(data)

    return dataset, train_dataset, test_dataset, mappings


class NCF(nn.Module):
    def __init__(self, num_users, num_items, embed_dim=32, linear_dims = [64, 32], mappings=None):
        super(NCF, self).__init__()
        self.user_embedding = nn.Embedding(num_users, embed_dim)
        self.item_embedding = nn.Embedding(num_items, embed_dim)
        self.idx_to_item = mappings['idx_to_item']
        self.item_to_idx = mappings['item_to_idx']
        self.user_to_idx = mappings['user_to_idx']
        self.idx_to_user = mappings['idx_to_user']

        # Add linear + relu layers
        layers = []
        input_dim = 2 * embed_dim
        output_dim = 1
        for dim in linear_dims:
            layers.append(nn.Linear(input_dim, dim))
            layers.append(nn.ReLU())
            input_dim = dim

        layers.append(nn.Linear(input_dim, output_dim))
        self.mlp = nn.Sequential(*layers)


    def forward(self, user, item):
        user_emb = self.user_embedding(user)
        item_emb = self.item_embedding(item)
        x = torch.cat([user_emb, item_emb], dim=1)
        
        return self.mlp(x).squeeze()
    
    
    
    def get_model_size(self):
        """
        This function will return the size of the model in bytes.
        Args:
            None
        Returns:
            int: The size of the model in bytes
        """

        return sum(p.numel() for p in self.parameters())

def train_tf(model, train_loader, optimizer, criterion):
    t0 = time.time()
    model.train()
    train_loss = 0
    for user, item, rating in train_loader:
        optimizer.zero_grad()
        output = model(user, item)
        loss = criterion(output, rating)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    return train_loss, time.time() - t0

def eval_tf(model, test_loader, criterion):
    model.eval()
    test_loss = 0
    t0 = time.time()
    with torch.no_grad():
        for user, item, rating in test_loader:
            output = model(user, item)
            loss = criterion(output, rating)
            test_loss += loss.item()

    return test_loss, time.time() - t0
    

def train(model, train_data, test_data, epochs=10, lr=0.001, bs=64):
    train_loader = DataLoader(train_data, batch_size=bs, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=bs, shuffle=False)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    
    t0 = time.time()

    for epoch in range(epochs):
        train_loss, train_time = train_tf(model, train_loader, optimizer, criterion)
        test_loss, test_time = eval_tf(model, test_loader, criterion)

        print(f'Epoch {epoch + 1}/{epochs}. Time = {train_time+test_time} s\n    - Train Loss (MSE): {train_loss / len(train_loader)}\n    - Test Loss (MSE): {test_loss / len(test_loader)}')
    print(f'Total Training time: {time.time() - t0} s')


def predict_movies(user_id, model, data, mappings, n):
    user_idx = mappings['user_to_idx'][user_id]

    all_movies = data['movie_id'].unique()
    watched_movies = data[data['user_id'] == user_id]['movie_id'].unique()
    not_watched_movies = np.setdiff1d(all_movies, watched_movies)

    # Convert numerical movie IDs back to their original titles
    not_watched_movies = [mappings['idx_to_item'][movie_id] for movie_id in not_watched_movies if movie_id in mappings['idx_to_item']]

    # Ensure movie IDs match the trained model's item_to_idx
    valid_movies = [movie_id for movie_id in not_watched_movies if movie_id in model.item_to_idx]

    user_tensor = torch.tensor([user_idx] * len(valid_movies), device=device)
    movie_tensors = torch.tensor([model.item_to_idx[movie_id] for movie_id in valid_movies], device=device)

    predictions = model(user_tensor, movie_tensors).detach().cpu().numpy()

    top_predictions = sorted(zip(valid_movies, predictions), key=lambda x: x[1], reverse=True)[:n]
    top_predictions = [(idx, min(5, max(1, pred))) for idx, pred in top_predictions]

    return top_predictions

if __name__ == '__main__':
        
    # Load the data
    data = pd.read_csv('data/recommendation_data.csv')

    unique_users = data['user_id'].unique()
    unique_movies = data['movie_id'].unique()
    
    # # Prepare the data
    dataset, train_data, test_data, mappings = prepare_data(data)
    # train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
    # test_loader = DataLoader(test_data, batch_size=64, shuffle=False)
    
    # # Train the model
    # model = NCF(len(unique_users), len(unique_movies), 64, [64, 128, 64], mappings=mappings).to(device)
    # train(model, train_data, test_data, epochs=4, lr=0.001, bs=64)

    # # Save model
    # save_model(model, 'ncf_model')

    model = load_model('ncf_model')

# %%
# Load and merge user data with model predictions
user_df = pd.read_csv('data/user_data_full.csv')
recommendations = pd.read_csv('data/recommendation_data.csv')
merged_df = pd.merge(user_df, recommendations, on="user_id")

# Sample some users for WIT
sample_df = merged_df.sample(100)
wit_inputs = sample_df.to_dict(orient='records')

# %%
class DummyModel:
    def predict_movies(user_id, model, data, mappings, n):
        user_idx = mappings['user_to_idx'][user_id]
    
        all_movies = data['movie_id'].unique()
        watched_movies = data[data['user_id'] == user_id]['movie_id'].unique()
        not_watched_movies = np.setdiff1d(all_movies, watched_movies)
    
        # Convert numerical movie IDs back to their original titles
        not_watched_movies = [mappings['idx_to_item'][movie_id] for movie_id in not_watched_movies if movie_id in mappings['idx_to_item']]
    
        # Ensure movie IDs match the trained model's item_to_idx
        valid_movies = [movie_id for movie_id in not_watched_movies if movie_id in model.item_to_idx]
    
        user_tensor = torch.tensor([user_idx] * len(valid_movies), device=device)
        movie_tensors = torch.tensor([model.item_to_idx[movie_id] for movie_id in valid_movies], device=device)
    
        predictions = model(user_tensor, movie_tensors).detach().cpu().numpy()
    
        top_predictions = sorted(zip(valid_movies, predictions), key=lambda x: x[1], reverse=True)[:n]
        top_predictions = [(idx, min(5, max(1, pred))) for idx, pred in top_predictions]

        return top_predictions
        
model = DummyModel()

# %%
# !pip install tensorflow witwidget pandas numpy torch notebook
# Out:
# Requirement already satisfied: tensorflow in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (2.19.0)
# Requirement already satisfied: witwidget in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (1.8.1)
# Requirement already satisfied: pandas in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: torch in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (2.6.0)
# Collecting notebook
#   Downloading notebook-7.3.3-py3-none-any.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 34.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wrapt>=1.11.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: packaging in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras>=3.5.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: six>=1.12.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: setuptools in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from witwidget) (8.1.5)
# Requirement already satisfied: oauth2client>=4.1.3 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from witwidget) (4.1.3)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from witwidget) (2.165.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: filelock in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: fsspec in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: networkx in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Collecting jupyterlab<4.4,>=4.3.6
#   Downloading jupyterlab-4.3.6-py3-none-any.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 35.9 MB/s eta 0:00:0000:0100:01
# Collecting jupyterlab-server<3,>=2.27.1
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 8.0 MB/s eta 0:00:00
# Collecting tornado>=6.2.0
#   Downloading tornado-6.4.2-cp38-abi3-macosx_10_9_universal2.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.3/436.3 kB 31.5 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 32.5 MB/s eta 0:00:00
# Collecting notebook-shim<0.3,>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->witwidget) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->witwidget) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->witwidget) (2.38.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->witwidget) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->witwidget) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->witwidget) (8.34.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->witwidget) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->witwidget) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->witwidget) (3.0.13)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->witwidget) (5.14.3)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting anyio>=3.1.0
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 16.7 MB/s eta 0:00:00
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 17.5 MB/s eta 0:00:00
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting prometheus-client>=0.9
#   Using cached prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# Collecting jupyter-client>=7.4.4
#   Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 20.2 MB/s eta 0:00:00
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 28.3 MB/s eta 0:00:00
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting pyzmq>=24
#   Downloading pyzmq-26.3.0-cp310-cp310-macosx_10_15_universal2.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.3 MB/s eta 0:00:0000:01
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting tomli>=1.2.2
#   Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Collecting ipykernel>=6.5.0
#   Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 8.0 MB/s eta 0:00:00
# Collecting httpx>=0.25.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.9 MB/s eta 0:00:00
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.6 MB/s eta 0:00:00
# Collecting babel>=2.10
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 35.6 MB/s eta 0:00:0000:010:01
# Collecting json5>=0.9.0
#   Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: namex in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: rich in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from oauth2client>=4.1.3->witwidget) (0.4.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from oauth2client>=4.1.3->witwidget) (0.6.1)
# Requirement already satisfied: rsa>=3.1.4 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from oauth2client>=4.1.3->witwidget) (4.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.2.2)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.7.8->witwidget) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.7.8->witwidget) (1.69.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.7.8->witwidget) (5.5.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.7.8->witwidget) (3.2.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 10.3 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
# Collecting psutil
#   Downloading psutil-7.0.0-cp36-abi3-macosx_11_0_arm64.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 12.2 MB/s eta 0:00:00
# Collecting appnope
#   Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.8.13-py2.py3-none-any.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 32.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.6->notebook) (0.1.7)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: decorator in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (2.19.1)
# Requirement already satisfied: stack_data in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (4.9.0)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.6 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.23.1-cp310-cp310-macosx_11_0_arm64.whl (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.8/356.8 kB 16.1 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.3.7-py3-none-any.whl (18 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 12.8 MB/s eta 0:00:00
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 kB 10.8 MB/s eta 0:00:00
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.8 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 9.4 MB/s eta 0:00:00
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: ptyprocess in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (0.8.4)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: mdurl~=0.1 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: wcwidth in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (0.2.13)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.17.1-cp310-cp310-macosx_11_0_arm64.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.6/178.6 kB 18.3 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jemyli/.pyenv/versions/3.10.12/envs/wit-env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->witwidget) (0.2.3)
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 8.9 MB/s eta 0:00:00
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.8 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, fastjsonschema, websocket-client, webcolors, uri-template, types-python-dateutil, tornado, tomli, tinycss2, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyzmq, pyyaml, python-json-logger, pycparser, psutil, prometheus-client, platformdirs, pandocfilters, overrides, nest-asyncio, mistune, jupyterlab-pygments, jsonpointer, json5, h11, fqdn, defusedxml, debugpy, bleach, babel, attrs, async-lru, appnope, terminado, referencing, jupyter-core, httpcore, cffi, beautifulsoup4, arrow, anyio, jupyter-server-terminals, jupyter-client, jsonschema-specifications, isoduration, httpx, argon2-cffi-bindings, jsonschema, ipykernel, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
# Successfully installed anyio-4.9.0 appnope-0.1.4 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 attrs-25.3.0 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 cffi-1.17.1 debugpy-1.8.13 defusedxml-0.7.1 fastjsonschema-2.21.1 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 ipykernel-6.29.5 isoduration-20.11.0 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-client-8.6.3 jupyter-core-5.7.2 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.6 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 nest-asyncio-1.6.0 notebook-7.3.3 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 platformdirs-4.3.7 prometheus-client-0.21.1 psutil-7.0.0 pycparser-2.22 python-json-logger-3.3.0 pyyaml-6.0.2 pyzmq-26.3.0 referencing-0.36.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.23.1 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 terminado-0.18.1 tinycss2-1.4.0 tomli-2.2.1 tornado-6.4.2 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
from witwidget.notebook.visualization import WitWidget, WitConfigBuilder

examples = [{'feature': 5, 'label': 1}, {'feature': 2, 'label': 0}]
config = WitConfigBuilder(examples).set_label_feature('label')
WitWidget(config)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow.py:58
#      56   sys.setdlopenflags(_default_dlopen_flags | ctypes.RTLD_LOCAL)
# ---> 58 from tensorflow.python.pywrap_tensorflow_internal import *
#      59 from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:28
#      27         return _mod
# ---> 28 _pywrap_tensorflow_internal = swig_import_helper()
#      29 del swig_import_helper
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:15, in swig_import_helper()
#      14 from os.path import dirname
# ---> 15 import imp
#      16 fp = None
#
# ModuleNotFoundError: No module named 'imp'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from witwidget.notebook.visualization import WitWidget, WitConfigBuilder
#       3 examples = [{'feature': 5, 'label': 1}, {'feature': 2, 'label': 0}]
#       4 config = WitConfigBuilder(examples).set_label_feature('label')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/witwidget/notebook/visualization.py:17
#      15 """Visualization API."""
#      16 import sys
# ---> 17 import tensorflow as tf
#      20 def _is_colab():
#      21   return "google.colab" in sys.modules
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/__init__.py:24
#      21 import os as _os
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      26 try:
#      27   # Add `estimator` attribute to allow access to estimator APIs via
#      28   # "tf.estimator..."
#      29   from tensorflow.python.estimator.api import estimator  # pylint: disable=g-import-not-at-top
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/__init__.py:49
#      32 # TODO(drpng): write up instructions for editing this file in a doc and point to
#      33 # the doc instead.
#      34 # If you want to edit this file to expose modules in public tensorflow API, you
#    (...)
#      44 # go/tf-wildcard-import
#      45 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      47 import numpy as np
# ---> 49 from tensorflow.python import pywrap_tensorflow
#      51 from tensorflow.python.tools import component_api_helper
#      52 component_api_helper.package_hook(
#      53     parent_package_str='tensorflow.python',
#      54     child_package_str=(
#      55         'tensorflow_estimator.python.estimator'))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow.py:74
#      69 except ImportError:
#      70   msg = """%s\n\nFailed to load the native TensorFlow runtime.\n
#      71 See https://www.tensorflow.org/install/errors\n
#      72 for some common reasons and solutions.  Include the entire stack trace
#      73 above this error message when asking for help.""" % traceback.format_exc()
# ---> 74   raise ImportError(msg)
#      76 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 15, in swig_import_helper
#     import imp
# ModuleNotFoundError: No module named 'imp'
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
from witwidget.notebook.visualization import WitWidget, WitConfigBuilder

config = WitConfigBuilder(wit_inputs).set_custom_predict_fn(model.predict_movies)
wit = WitWidget(config)
wit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow.py:58
#      56   sys.setdlopenflags(_default_dlopen_flags | ctypes.RTLD_LOCAL)
# ---> 58 from tensorflow.python.pywrap_tensorflow_internal import *
#      59 from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:28
#      27         return _mod
# ---> 28 _pywrap_tensorflow_internal = swig_import_helper()
#      29 del swig_import_helper
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:15, in swig_import_helper()
#      14 from os.path import dirname
# ---> 15 import imp
#      16 fp = None
#
# ModuleNotFoundError: No module named 'imp'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from witwidget.notebook.visualization import WitWidget, WitConfigBuilder
#       3 config = WitConfigBuilder(wit_inputs).set_custom_predict_fn(model.predict_movies)
#       4 wit = WitWidget(config)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/witwidget/notebook/visualization.py:17
#      15 """Visualization API."""
#      16 import sys
# ---> 17 import tensorflow as tf
#      20 def _is_colab():
#      21   return "google.colab" in sys.modules
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/__init__.py:24
#      21 import os as _os
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      26 try:
#      27   # Add `estimator` attribute to allow access to estimator APIs via
#      28   # "tf.estimator..."
#      29   from tensorflow.python.estimator.api import estimator  # pylint: disable=g-import-not-at-top
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/__init__.py:49
#      32 # TODO(drpng): write up instructions for editing this file in a doc and point to
#      33 # the doc instead.
#      34 # If you want to edit this file to expose modules in public tensorflow API, you
#    (...)
#      44 # go/tf-wildcard-import
#      45 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      47 import numpy as np
# ---> 49 from tensorflow.python import pywrap_tensorflow
#      51 from tensorflow.python.tools import component_api_helper
#      52 component_api_helper.package_hook(
#      53     parent_package_str='tensorflow.python',
#      54     child_package_str=(
#      55         'tensorflow_estimator.python.estimator'))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow.py:74
#      69 except ImportError:
#      70   msg = """%s\n\nFailed to load the native TensorFlow runtime.\n
#      71 See https://www.tensorflow.org/install/errors\n
#      72 for some common reasons and solutions.  Include the entire stack trace
#      73 above this error message when asking for help.""" % traceback.format_exc()
# ---> 74   raise ImportError(msg)
#      76 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 15, in swig_import_helper
#     import imp
# ModuleNotFoundError: No module named 'imp'
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
# !python3 --version
# Out:
# Python 3.10.12
